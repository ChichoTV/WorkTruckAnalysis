# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# > First, we need to read in the DF we cleaned up in data_exploration.ipynb. We also need to convert the data types again it seems.

# %%
df=pd.read_csv('resources/clean_with_prices.csv')
df=df.set_index('VIN')
call_pricing_df=df.loc[df['price']=='Call for Pricing'].reset_index().drop(['price','Stock #','Color','VIN'],axis=1)
prices_df=df.drop(df.loc[df['price']=='Call for Pricing'].index)
converted_df=prices_df.convert_dtypes()
converted_df['price']=round(converted_df['price'].astype(float),2)
converted_df['Color']=[x.lower() for x in converted_df['Color']]
converted_df
# Out:
#                      price Stock #   Cab Type Drivetrain Rear Wheels  \
# VIN
# 3GCUYEEL8LG244537  72000.0  201909       Crew        4x4         SRW
# 3GCPWBEK2MG268102  34220.0  210982       Crew        4x2         SRW
# 1GCPWCED1MZ218282  40950.0  210714       Crew        4x2         SRW
# 1GCPWCED0MZ218354  40950.0  210713       Crew        4x2         SRW
# 3GCUYEEL2MG171084  78155.0  210884       Crew        4x4         SRW
# ...                    ...     ...        ...        ...         ...
# 3GCUKSEC6FG413541  51035.0   U5982       Crew        4x4         SRW
# 1FTFW1E1XMFB18575  67215.0  T21832  SuperCrew        4x4         SRW
# 3GCPYBEK6MG294289  42310.0   40545       Crew        4x4         SRW
# 3GCUYEETXMG154159  55375.0   40473       Crew        4x4         SRW
# 3GCUWCED7KG242618  39949.0  40472A       Crew        4x2         SRW
#
#                   Fuel Type        Transmission               Color  \
# VIN
# 3GCUYEEL8LG244537  Gasoline  10-Speed Automatic                 red
# 3GCPWBEK2MG268102  Gasoline   8-Speed Automatic               white
# 1GCPWCED1MZ218282  Gasoline   8-Speed Automatic               white
# 1GCPWCED0MZ218354  Gasoline   8-Speed Automatic               white
# 3GCUYEEL2MG171084  Gasoline  10-Speed Automatic               black
# ...                     ...                 ...                 ...
# 3GCUKSEC6FG413541  Gasoline           automatic  deep ruby metallic
# 1FTFW1E1XMFB18575    Diesel  10-Speed Automatic               white
# 3GCPYBEK6MG294289  Gasoline           Automatic               black
# 3GCUYEETXMG154159    Diesel           Automatic        summit white
# 3GCUWCED7KG242618  Gasoline           Automatic              silver
#
#                   Vehicle Trim
# VIN
# 3GCUYEEL8LG244537          RST
# 3GCPWBEK2MG268102       Custom
# 1GCPWCED1MZ218282           LT
# 1GCPWCED0MZ218354           LT
# 3GCUYEEL2MG171084          RST
# ...                        ...
# 3GCUKSEC6FG413541          LTZ
# 1FTFW1E1XMFB18575       Lariat
# 3GCPYBEK6MG294289       Custom
# 3GCUYEETXMG154159          RST
# 3GCUWCED7KG242618           LT
#
# [6896 rows x 9 columns]

# %% [markdown]
# > Next, we need to preprocess the data by encoding all of our categorical features and splitting up the data into training and testing. We will omit color as features for now since we can assume this doesn't affect price meaningfuly. Shown below is the encoded feature set.

# %%
y=converted_df['price']
encoder=LabelEncoder()
X=converted_df.iloc[:,2:9].reset_index().drop(['VIN','Color'],axis=1)
for col in X:
    X[col]=encoder.fit_transform(X[col])
    call_pricing_df[col]=encoder.fit_transform(call_pricing_df[col])
print(X) 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
#       Cab Type  Drivetrain  Rear Wheels  Fuel Type  Transmission  Vehicle Trim
# 0            0           1            1          4             1           190
# 1            0           0            1          4            26            63
# 2            0           0            1          4            26           136
# 3            0           0            1          4            26           136
# 4            0           1            1          4             1           190
# ...        ...         ...          ...        ...           ...           ...
# 6891         0           1            1          4            54           146
# 6892         7           1            1          1             1           155
# 6893         0           1            1          4            42            63
# 6894         0           1            1          1            42           190
# 6895         0           0            1          4            42           136
#
# [6896 rows x 6 columns]

# %%
def plot_complexity_curve(k_list, knn_model, x_train, x_test, y_train, y_test):
    
    train_scores = []
    test_scores = []
    
    # For each k
    for k in k_list:
        # Initialize, fit, predict
        knn = knn_model(k)
        
        knn.fit(x_train, y_train)
        
        train_scores.append(knn.score(x_train, y_train))
        test_scores.append(knn.score(x_test, y_test))

    # Plot
    fig, ax = plt.subplots()
    
    ax.plot(k_list, train_scores, label='Training Accuracy', color='red')
    ax.plot(k_list, test_scores, label='Testing Accuracy', color='black')

    ax.set(title='k-NN with Different Values for $k$',
           xlabel='Number of Neighbors',
           ylabel='Accuracy')
    
    ax.legend()

# %% [markdown]
# > k=6 seems like our best bet.

# %%
k=np.arange(1,20)
plot_complexity_curve(k, KNeighborsRegressor, X_train, X_test, y_train, y_test)

# %%
knnR=KNeighborsRegressor(n_neighbors=6)
knnR.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                     weights='uniform')

# %% [markdown]
# > Now we use our model to generate a DF with the new predicted value for each of the 'Call for Pricing' listings.

# %%
predicted_df=df.copy().loc[df['price']=='Call for Pricing'].rename(columns={'price':'predicted price'})
predicted_df['predicted price']=knnR.predict(call_pricing_df).round(2)
predicted_df.to_csv('resources/predicted_price.csv')
predicted_df
# Out:
#                    predicted price     Stock # Cab Type Drivetrain  \
# VIN
# 3GCPWAEHXMG239509         43301.83      210846     Crew        4x2
# 1C6SRFJTXMN698885         44763.67      C18375     Crew        4x4
# 1C6SRFFT0MN697446         39452.00      C18354     Crew        4x4
# 3C6UR5NL4MG582958         52152.17      C18360     Mega        4x4
# 3C6UR5NL6MG582959         52152.17      C18376     Mega        4x4
# ...                            ...         ...      ...        ...
# 1FTFX1E59MKD90753         43242.33  MX1E0002*O    Super        4x4
# 1FTMF1EP0MKD90748         44075.67  MF1E0003*O  Regular        4x4
# 1GTU9BED5LZ229515         43301.83       CH900     Crew        4x4
# 1GTU9BED8LZ228603         43301.83       CH910     Crew        4x4
# 1GTU9DED4KZ374829         43301.83       CH930     Crew        4x4
#
#                   Rear Wheels Fuel Type  \
# VIN
# 3GCPWAEHXMG239509         SRW  Gasoline
# 1C6SRFJTXMN698885         SRW  Gasoline
# 1C6SRFFT0MN697446         SRW  Gasoline
# 3C6UR5NL4MG582958         SRW    Diesel
# 3C6UR5NL6MG582959         SRW    Diesel
# ...                       ...       ...
# 1FTFX1E59MKD90753         SRW  Gasoline
# 1FTMF1EP0MKD90748         SRW  Gasoline
# 1GTU9BED5LZ229515         SRW  Gasoline
# 1GTU9BED8LZ228603         SRW  Gasoline
# 1GTU9DED4KZ374829         SRW  Gasoline
#
#                                                   Transmission  \
# VIN
# 3GCPWAEHXMG239509  6-Speed Automatic Electronic with Overdrive
# 1C6SRFJTXMN698885         8-Speed Automatic 8HP75 Transmission
# 1C6SRFFT0MN697446         8-Speed Automatic 8HP75 Transmission
# 3C6UR5NL4MG582958         6-Speed Automatic 68RFE Transmission
# 3C6UR5NL6MG582959         6-Speed Automatic 68RFE Transmission
# ...                                                        ...
# 1FTFX1E59MKD90753                                    Automatic
# 1FTMF1EP0MKD90748                                    Automatic
# 1GTU9BED5LZ229515                            8-Speed Automatic
# 1GTU9BED8LZ228603                            8-Speed Automatic
# 1GTU9DED4KZ374829                            8-Speed Automatic
#
#                                              Color  \
# VIN
# 3GCPWAEHXMG239509                            White
# 1C6SRFJTXMN698885                    Maximum Steel
# 1C6SRFFT0MN697446                             Tank
# 3C6UR5NL4MG582958  Diamond Black Crystal Pearlcoat
# 3C6UR5NL6MG582959                  Granite Crystal
# ...                                            ...
# 1FTFX1E59MKD90753                     Oxford White
# 1FTMF1EP0MKD90748                     Oxford White
# 1GTU9BED5LZ229515                     Summit White
# 1GTU9BED8LZ228603                     Summit White
# 1GTU9DED4KZ374829             Quicksilver Metallic
#
#                                     Vehicle Trim
# VIN
# 3GCPWAEHXMG239509                             WT
# 1C6SRFJTXMN698885   LARAMIE CREW CAB 4X4 5'7 BOX
# 1C6SRFFT0MN697446  BIG HORN CREW CAB 4X4 5'7 BOX
# 3C6UR5NL4MG582958   LARAMIE MEGA CAB 4X4 6'4 BOX
# 3C6UR5NL6MG582959   LARAMIE MEGA CAB 4X4 6'4 BOX
# ...                                          ...
# 1FTFX1E59MKD90753                             XL
# 1FTMF1EP0MKD90748                             XL
# 1GTU9BED5LZ229515                            SLE
# 1GTU9BED8LZ228603                            SLE
# 1GTU9DED4KZ374829                            SLT
#
# [1591 rows x 9 columns]
